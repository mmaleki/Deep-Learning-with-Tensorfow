# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow.compat.v2 as tf

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
x_in = np.array([[
  [[2], [1], [2], [0], [1]],
  [[1], [3], [2], [2], [3]],
  [[1], [1], [3], [3], [0]],
  [[2], [2], [0], [1], [1]],
  [[0], [0], [3], [1], [2]], ]])

# %%
kernel_in = np.array([
 [ [[2, 0.1]], [[3, 0.2]] ],
 [ [[0, 0.3]],[[1, 0.4]] ], ])

# %%
x = tf.constant(x_in, dtype=tf.float32)

# %%
kernel = tf.constant(kernel_in, dtype=tf.float32)

# %%
tt=tf.nn.conv2d(x, kernel, strides=[1, 1, 1, 1], padding='VALID')

# %%
from tensorflow import keras

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
image = img.imread("rabbit.jpg")
#image=image[::-1] 
image=image[::-1]
plt.figure(figsize = (10, 10))
plt.imshow(image)

# %%
green_channel = image[:,:, 1]
 
plt.figure(figsize = (10, 10))
plt.imshow(green_channel, cmap="gray")

# %%
krn=np.array([[0,0],
              [1,1]])

# %%
green_channel2 = image[200:800,1000:1500, 1]
 
plt.figure(figsize = (10, 10))
plt.imshow(green_channel2, cmap="gray")
