# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk import word_tokenize
from nltk import sent_tokenize

# %%
twitter=pd.read_csv('twitter.csv',header=None,encoding='latin-1')

# %%
twitter=twitter.sample(frac=1)

# %%
twitter.to_csv("twitter3.csv",header=None)

# %%
twitter=pd.read_csv('twitter3.csv',header=None,encoding='latin-1')

# %%
twitter=twitter[:500000]

# %%
twitter.head(5)
# Out:
#          0  1           2                             3         4  \
# 0   638217  0  2234397387  Thu Jun 18 22:58:59 PDT 2009  NO_QUERY
# 1   310252  0  2001068452  Mon Jun 01 23:45:00 PDT 2009  NO_QUERY
# 2   741527  0  2266288730  Sun Jun 21 08:14:37 PDT 2009  NO_QUERY
# 3   876991  4  1684874865  Sat May 02 22:19:00 PDT 2009  NO_QUERY
# 4  1124080  4  1974609374  Sat May 30 13:29:03 PDT 2009  NO_QUERY
#
#              5                                                  6
# 0    edashwood  On my way to work,btw it's 8 at morning in Ger...
# 1       josrox  @Sarcia sorry! I've been busy so haven't even ...
# 2   mmckayylaa  @ELLEohhELLExxx i know  we need to start texti...
# 3  littlejojoe  @AJEntertainment and I'm here aswell looking a...
# 4    ShayBears                One of six people to gets callback

# %%
sen=twitter[6]

# %%
twitter[6][2]
# Out:
# '@ELLEohhELLExxx i know  we need to start texting/fb or some shit. &lt;3'

# %%
sent=[sen[i].lower() for i in range(len(twitter))]

# %%
tag=twitter[1]

# %%
twitter[1][2]
# Out:
# 0

# %%
len(twitter)
# Out:
# 500000

# %%
def p(v):
    return len(tag[tag==v])/(len(twitter))

# %%
p(0)
# Out:
# 0.49966

# %%
p(4)
# Out:
# 0.50034

# %%
ls={}
for i in range(4):
    ls["l{}".format(i)]=''
    for s in sent[i*100000:(i+1)*100000]:
        ls["l{}".format(i)]=s+ls["l{}".format(i)]

# %%
l=''
for i in range(4):
    l=ls['l{}'.format(i)]+l

# %%
vocabulary=word_tokenize(l)

# %%
vocabulary[:10]
# Out:
# ['@', 'neyn', 'watched', 'apa', '?', 'iyanih', 'emang', 'kesel', 'bgt', 'udh']

# %%
len(vocabulary)
# Out:
# 6488446

# %%
voc=set(vocabulary)

# %%
len(voc)
# Out:
# 324167

# %%
voc
# Out:
# {'olã\x83â¡',
#  'nikki_0429',
#  'readyy..',
#  'arrngmnts',
#  'sweetness28',
#  'faison',
#  'ching',
#  'stable..',
#  'incoming',
#  'dugan',
#  'exorbitantly',
#  'crepevine',
#  'gagause',
#  'devostated',
#  'escuchando',
#  'kunstiajaloole',
#  'catalogue',
#  'thebuxt',
#  'tigermarketing',
#  'oeh',
#  'laffing',
#  'lyndseyparker',
#  'quiet.home',
#  'puc',
#  'mshymaintenance',
#  'ntmartin',
#  'caffeinateme',
#  'next.just',
#  'rosegalaxy',
#  'partaayy',
#  'deeeaaarrr',
#  'excelling',
#  'yess..',
#  'sarahmarkley',
#  'melissa15678',
#  'fresheners',
#  'ireneangella',
#  'rev',
#  '//plurk.com/p/x5loeabout',
#  'pikcing',
#  'lol.its',
#  'lately..',
#  'beautythrucolor',
#  'shartlesville',
#  'dollasmy',
#  'wherever..',
#  'cornelia',
#  'trtying',
#  'za5',
#  'taboulichic',
#  "poynter'sday",
#  'hannahheroine12',
#  '324',
#  'pandol',
#  'rijn',
#  'rkellys',
#  'riny',
#  'kyrobbins',
#  'tweetgenius',
#  'then.pastor',
#  '_kris_tina_',
#  '//twitpic.com/5oo9c',
#  'antarctica',
#  'grrrrrrrrrrrrrrrrrrr',
#  'tinachhabra',
#  'quantities',
#  'ambersimmons',
#  'wilkins',
#  'craky',
#  'taaaschi',
#  'ghowley',
#  'flavamen',
#  'futureanybodyyyyy',
#  'cinnamon_kane',
#  'alison1788',
#  'gorgeousgenius',
#  'jennypennifer',
#  'sidrox123you',
#  'naaaww',
#  'fun..too',
#  'flow..its',
#  'fblistening',
#  'deep',
#  'dearlennon',
#  'havainas',
#  '//bit.ly/vawkj',
#  '//bit.ly/1ahqvu',
#  'shawn',
#  'mrsclaus25',
#  'devanp16',
#  'franks',
#  'laydeexsantha',
#  'nite1',
#  'samuel_l_bronko',
#  'languageplease',
#  '//is.gd/cjrj',
#  'in-',
#  'p.i',
#  'sgturtle',
#  'that.mmm',
#  'morining',
#  'wakeup_maggie',
#  '//tinyurl.com/mh9ta3',
#  'kaylynashleyy',
#  'googleooof',
#  'mcflyinargentinacold',
#  'sheenadawson',
#  'gingy23',
#  'ilovetickets',
#  'ten..',
#  'plumberzcrack',
#  'ozboxlive',
#  'tonigh',
#  'brown..',
#  'lidiw00t',
#  'djratxxx',
#  'waist-line',
#  'croppley',
#  'theemzi',
#  '//twitpic.com/6fy09',
#  'shawnknightshow',
#  'dvds',
#  'rape.would',
#  'arrrrrrrrgh',
#  'rockstarjen',
#  'plumpgoddess',
#  '..xoxo',
#  'tireed',
#  'blondechicken',
#  'armload',
#  'preformed',
#  'emmiri',
#  'hjaybee',
#  'mojolocollc',
#  '3drinking',
#  'vivian',
#  'acl',
#  'chizzzy79',
#  'yeyz',
#  'ellen_82',
#  'andydiggle',
#  'thenoblesavage',
#  'restaurant..how',
#  "'talk",
#  'throughã¯â¿â½',
#  'johnmarsden',
#  'rks',
#  'mysto',
#  'nathaneide',
#  'iamashleyblue',
#  'jkozuch',
#  'nopawn',
#  'madamejewels',
#  'taisen',
#  '0.01',
#  'loltruthfully',
#  'crispywaffle',
#  'hard.coooooollllllllldddddddddd',
#  'huddlesuz',
#  'hobbling',
#  'sweetspiced',
#  '4barca',
#  'reims',
#  'harry-legs',
#  'day.ugh',
#  'saxondale',
#  'foregoing',
#  'finnaally',
#  '_jessicastudley',
#  'garrymcdonald',
#  'purnima',
#  'mjemdjee',
#  'arigusx207',
#  'cinematography',
#  'youthfullyyoked',
#  'johnnywalnuts',
#  'alfa_maniac',
#  's.o.i',
#  'alex_florov',
#  'lemay',
#  'handshakes',
#  'g.mornin',
#  'wuth',
#  'day..sad',
#  '35secs',
#  '//www.layar.eu',
#  'dyslexics',
#  'tomz',
#  'puggy',
#  'shipper',
#  'exo',
#  'bhambo',
#  'charity',
#  'heehow',
#  'ruko',
#  'jenniferpelland',
#  'mariurdaneta',
#  'misslovely310',
#  '//blip.fm/~6g3fo',
#  'â¶ã¨â\x87âªã§â\x84â¶..',
#  'dahveed76',
#  'kkozmic',
#  'etc.my',
#  'reiman',
#  'hmm..sorcha',
#  'jennifilman',
#  'brownszoo',
#  'outwith',
#  'lookafraid',
#  'chapatti',
#  'omgitsjustintrstill',
#  'bettaaaa',
#  'terrifying',
#  'sunbasilgarden',
#  'traceyohara',
#  'nackerddd',
#  'arvika',
#  'yayywonders',
#  'krist0ph3r',
#  'shame',
#  'ingadurgin',
#  'comiong',
#  'kookykitten',
#  'lilpurs',
#  '//blip.fm/~7qi8o',
#  'trishiro',
#  'webchickbot',
#  'boring/i',
#  'yougunna',
#  'kennyjcomedy',
#  'dialated',
#  'look/layout',
#  'tomorrow.no',
#  'nadili',
#  '.ã£â',
#  'cyclist',
#  'wineebtm.com',
#  'litmus',
#  '//tinyurl.com/9f9p4a',
#  'wtfomgftw',
#  'seatbelt',
#  'neeewwww',
#  'trevorwarren',
#  '//twitzap.com/u/cim',
#  '^^~',
#  'braden',
#  'musicmuch',
#  'donkeycharms',
#  'hotel_alpha',
#  'gabstaz',
#  'floorspace',
#  'koffiekoeken',
#  'hingham',
#  'jazzys',
#  'glencocco',
#  'classical-westren',
#  '*sigh*goodness',
#  'loveyouthe',
#  "'right",
#  'sufigirl35',
#  'christine_sc',
#  'tommitcham',
#  'nkblazenbury',
#  'ahhhhhhhhclient',
#  'earthquake',
#  'mark_wahlberg',
#  'flexing',
#  'blarney',
#  'dutchcelt',
#  '2.22',
#  'nfaustin',
#  'maaarjuuu',
#  'tiffthestylist',
#  'ice-coffee',
#  'klienty',
#  'consciousstream',
#  'ã\x90â²ã\x90â',
#  'christianward',
#  'betrayaled',
#  'neighborrtook',
#  'scottgingold',
#  'smooooothie.ok..2',
#  'xhypnotized',
#  'pagadian',
#  'thegathering',
#  'drums',
#  'sydnielew',
#  'ã¯â¿â½ver',
#  'scholarlyphases',
#  'daaaanny',
#  '_madison',
#  'landi',
#  "'un",
#  '//plurk.com/p/p6kuunight',
#  'absence.laying',
#  'atownsend0824',
#  'clcross27',
#  'efalase',
#  'avatari',
#  'aaloo-chaat',
#  'clubswing',
#  'hahaplease',
#  'squarespacegoooooodnight',
#  'fonte',
#  'shortstack.com.au',
#  'xxxxfreinds',
#  'ohappleda',
#  'aine1234',
#  'restrain',
#  'ip5000',
#  'lgd_x',
#  'mattshiloh',
#  'biancamoura',
#  'peppermint',
#  'suppositories',
#  '*like*',
#  'receipe',
#  'do.good',
#  'joecichu',
#  'realjessicaalba',
#  'jerry_oct26',
#  'wiennat',
#  'amandajansson',
#  'ashame',
#  'recitaaaal',
#  'puffs+',
#  'stappler',
#  'families..',
#  'discotit',
#  'megabreakfast',
#  'sinjax',
#  're-meeting',
#  'hmzzzz',
#  'lucket',
#  'bolster',
#  'raunchy',
#  'yastonebridge',
#  'plastiscines',
#  'hihi..',
#  'sarahs',
#  'swedishmike',
#  '//twitpic.com/5db2j',
#  'jdkrach',
#  'itsss',
#  'turrble',
#  'sun.sooooo',
#  'jjsemple',
#  'sepponet',
#  'gryffindorap',
#  'pragmaticloveme',
#  'ramkitten',
#  'dee__cee',
#  'jumbafund',
#  'yanna',
#  'innn',
#  'kabamm_',
#  'theerikho',
#  '//bit.ly/14si4mi',
#  'firemen',
#  'mamatucci',
#  '_sinequanon',
#  'hollyhatesyou',
#  'minsan',
#  '//plurk.com/p/xo73ugotta',
#  'dident',
#  'paradoxical',
#  'complexity_',
#  'realmrscott',
#  'toenails',
#  'dlegler',
#  'asaladaday',
#  'tellign',
#  'dapo',
#  'cbjason',
#  'hiks.tandoori',
#  'vdsudeep',
#  'group',
#  '//blip.fm/~7f39lsaturday',
#  'mehehehetoday',
#  'crã\x83â¼e',
#  'kalansay',
#  'dr_dinasadik',
#  'rnewbury',
#  'whitestrips',
#  'paulwallbaby',
#  'artin',
#  'nikil',
#  'cvangron',
#  'essentially',
#  'reagent',
#  'observatory',
#  '930',
#  'simbaki',
#  'diversityyyy',
#  'inasilver',
#  'chueymartinez',
#  'fisika',
#  'brettmusil',
#  'noel1215',
#  'tinyysmalls',
#  'transhawn',
#  'ladyxanth',
#  'weej',
#  'dbq',
#  'kysha_candygirl',
#  'week/month',
#  'cc4452,723147,31152bis',
#  '//bit.ly/7vgue',
#  'rhaissamorais',
#  "'we",
#  'activism',
#  'ninomcfly',
#  'twilight_freakk',
#  'wpmu',
#  'heeeeeeeeeelp',
#  '//ff.im/3ovutsome',
#  'hayate..',
#  'youlovejackie',
#  'nyobain',
#  'britpop',
#  'starrdance',
#  'garretjames',
#  'firnds',
#  'lucyannabel',
#  'aussienick',
#  'princeton',
#  'mhaithaca',
#  'omgharrypotter',
#  'omfg',
#  'bregfust',
#  'annatatham',
#  'intheloopnyc',
#  "'brian",
#  'jessickers',
#  'fallen_reason',
#  'walletpop',
#  'analytically',
#  'makeover',
#  'molecat84',
#  'jenniflakes',
#  'kbg',
#  'facebook.com/dawnintahoe',
#  'xxhmmm',
#  'thekidfamous',
#  'tought',
#  'jbmaremarejb',
#  'tinatwitt',
#  '18664365710',
#  'lilluci44',
#  'tiny_winchester',
#  'shirumi',
#  'pixelexecution',
#  'jade_e_e',
#  'filmladd',
#  'johnhalton',
#  'damianlongoria',
#  'ashleyjaydot',
#  'wendhall',
#  'picnick',
#  'day5a',
#  'chess',
#  'enables',
#  'niã\x83â±a',
#  'rawritsria',
#  'lword',
#  'wio',
#  'lyn33',
#  'knife',
#  'spacejock',
#  'twittykris',
#  'b.no',
#  '//twitpic.com/4ebyki',
#  '..kinda',
#  'despite',
#  'parrots',
#  'vodkaaaa',
#  'streped',
#  'pop-',
#  'lynseybutterfly',
#  'firstrecord',
#  'suupa',
#  'whispher',
#  'calculation',
#  'shinginbox',
#  'mikachu84',
#  'artemis74',
#  'wellmaking',
#  'awesuumgoing',
#  'nicole_reyes',
#  'justplaingeoff',
#  'peterbaltes',
#  '.little',
#  '4rm',
#  '//plurk.com/p/tt320',
#  'mughaleazam',
#  'yipee',
#  'ksdaisy',
#  'suliet',
#  'â®ã£â\x83â\x9aã£â\x83â¼ã£â\x83â\x91ã£â\x83â¼ã£',
#  'backslidedness',
#  'lovelamps',
#  'manor',
#  'nameless',
#  'brandijobraun',
#  'janny',
#  'transporter',
#  'kathernandez',
#  'couch',
#  'takingstock',
#  'pdowellx1',
#  '-kill',
#  'gilangshanahan',
#  'lolwatching',
#  'kategunderson',
#  'seehh..',
#  'dizmeister',
#  'iconoguy',
#  'lag',
#  'danycarey',
#  'sngs',
#  'it..bangs',
#  'sleeepy',
#  'fishbowl',
#  'ktmgoodnight',
#  'owhhhhhh',
#  'twain',
#  'ysee',
#  'itsfameybaby',
#  'ok.losing',
#  'curfew',
#  'rutter',
#  'â\x86ã§â',
#  'inquires',
#  'diva_zura',
#  '//twitpic.com/6usfy',
#  'traciknoppe',
#  'heriotdale',
#  'helio',
#  '2-7',
#  'cheap.',
#  'mist',
#  'loving/hating',
#  'girlbeatsdrums',
#  'arm_candy',
#  'justinflitter',
#  'qlad',
#  '//loopt.us/-e2oxg.t',
#  '*____*',
#  'theorris',
#  'xxshopping',
#  'sonyarose',
#  'navarro',
#  'bluthngsx',
#  'skipper',
#  'taho',
#  'mooshinindy',
#  'polet',
#  'waise',
#  'yosoy220',
#  'bmdakin',
#  'andreaok',
#  'irish916',
#  'itchychoda',
#  'see..',
#  'matripley',
#  'stilly',
#  'salt-unfortunately-',
#  'with.wth',
#  'nerdfantastyfailomg',
#  'ucl-prize',
#  'superkas83',
#  'humpybong',
#  'zoo..and',
#  'burgersssss',
#  'jmee21',
#  'garseys',
#  'timanderic',
#  '//tumblr.com/x9r224gqtbummer',
#  'norrkã¯â¿â½ping',
#  'soon..looks',
#  'read/type',
#  'businessdiy',
#  ',hes',
#  'yaseen',
#  'worried',
#  'crisjobcoach',
#  'arandas',
#  'saturday.i',
#  'discriminating',
#  'ã¯â¿â½only',
#  'sodmg_brazil',
#  'storyofmylife',
#  'buã\x83â´n',
#  'sã¡âºâ¯p',
#  'stevenpage',
#  'kingjimmeh',
#  'strangedesign',
#  'katelundy',
#  'rickgarel',
#  'theycallmemons',
#  'ww',
#  'dramirezcr',
#  'thegrizzlygreek',
#  'marshallcooper',
#  'inniu',
#  'croatianfire',
#  'regressed',
#  'ouchblog',
#  'wedyn',
#  'sweetes',
#  'jitofbpe954',
#  'kaitlynmjonas',
#  'breannabonana',
#  'larissahessing',
#  'mackash',
#  'magsusulat',
#  'mismanages',
#  'bloodhorse',
#  'ajkx0',
#  'alolo',
#  'welshy',
#  'faces',
#  'danzingdonny',
#  'hullywood_bound',
#  'pinging',
#  'beta.bloglines.com',
#  'bellastellababy',
#  'cathyah',
#  '8q',
#  'richberra',
#  'wolfgangsee',
#  'to-i',
#  'abnormalities',
#  'batlidj',
#  'lovemusic247',
#  'bbezanson',
#  'bighead',
#  '//charcoalink.files.wordpress.com/2008/01/dorothy.jpg',
#  'score.-when',
#  'colorist',
#  'mcdonald..',
#  'kontemporer',
#  'shugo',
#  'prezi',
#  '//tumblr.com/x6s1wuy05',
#  'aweesome',
#  'script..',
#  'up.sizzlin',
#  'faithx5',
#  'vesuvio',
#  '//twitpic.com/7gl4c',
#  'chipmunk',
#  'chocoseduction',
#  'lohem',
#  'housed',
#  'justinkendall',
#  'traing',
#  'leti',
#  'koolkarthik',
#  'kuyakevin',
#  'grv',
#  'tmuethinf',
#  'talor',
#  'ebjohns11',
#  'missdiggs',
#  'haaar',
#  '-off',
#  '//plurk.com/p/z4396my',
#  'trigo',
#  'diamond_rockk',
#  'ainav',
#  'phigment',
#  'â\x82ã£',
#  'aaaaaaw',
#  'yum.rip',
#  'jamiiiaca.',
#  'millionairess',
#  'marveling',
#  'gokart',
#  '//twitpic.com/7gkxn',
#  'cubs/cards',
#  'colddd',
#  'lolchit',
#  'tely..',
#  'houri',
#  '//plurk.com/p/y2sl1wish',
#  'daveharte',
#  '*air',
#  'bagay..',
#  'emihnk',
#  'itsaw',
#  'tentunya',
#  '4international',
#  'chicane',
#  "ta'ing",
#  'mido',
#  'tooattached',
#  '/feeling',
#  'aggh',
#  'ohmigoodness',
#  '//blip.fm/~7nykr',
#  'wishwishwish',
#  'barter',
#  'program..',
#  'gws8',
#  'lol..was',
#  'skylinedreams',
#  'xour',
#  'letã¯â¿â½s',
#  'iheartphoto',
#  'tab1376',
#  'it_aint_kansas',
#  'lorigama',
#  '//plurk.com/p/y35hggoing',
#  'bright_rainbow',
#  'hubmum',
#  'solo1er',
#  'bienvenidos',
#  'iisapp.vbs',
#  'sallians',
#  'ellipticeye',
#  'zeldasavitri',
#  'alchemy',
#  'mohitos',
#  '11:49',
#  'bovising',
#  'jewelrybypatti',
#  'self-teaching',
#  'two-wheeled',
#  'monogram',
#  '3333333',
#  'hmsophie',
#  'canhasnameplz',
#  'patients',
#  'silentrunnning',
#  'emdiiemcii',
#  'dazb',
#  'britatany',
#  'joshkickjosh',
#  'spems',
#  'jasons',
#  'gobbled',
#  'iheartrachael',
#  'heylookitseric',
#  '.party',
#  'nets',
#  'experiences',
#  'carlalalababy',
#  'jambul',
#  'asafrommaui',
#  'bodit',
#  'asianpersuazion',
#  'frndz',
#  'twaveltwivia',
#  'pierred1',
#  'jameshillyer',
#  'j.f',
#  'georgewezsley',
#  'buzzing/nagging',
#  'v1ckio',
#  'co-op',
#  'ahhh-some',
#  'seannn',
#  'stacky6',
#  'calbo',
#  'bsbmy',
#  '*consolation',
#  'xp64',
#  '2go',
#  'donniewsboo09',
#  'mozambique',
#  '*yawwwwwwwn*',
#  'chopman',
#  'oils..',
#  'cubanalaf',
#  'mehtariel',
#  'owies',
#  'frackyland',
#  'leninists',
#  'evuuur.has',
#  'dext',
#  'polosport727',
#  'eeeeaaarrrrlllyyyyyyyy',
#  'darceywestcott',
#  'flyingphotog',
#  '.can',
#  'angelsjust',
#  '//tinyurl.com/pn2nyucoffe',
#  'steve_spence',
#  'week..lauryn',
#  'mcflyfreak',
#  'renã\x83â©e',
#  'spitphyre',
#  'maxima',
#  'dali',
#  'theredmage13',
#  'globo',
#  'lourdesdonis',
#  'clairabellejp',
#  'albertposis',
#  'sadalcholics',
#  'followersss',
#  'sammywhammmy',
#  'lady-like',
#  'yesssh',
#  'aba.eww',
#  'legendkiller50',
#  'jessssw',
#  'justsara08',
#  'redadamn',
#  'jangle',
#  'secretgoing',
#  'grand',
#  'pansit',
#  'ã\x90â°ã\x91â\x88ã\x90âµã\x90â½ã\x90â¸ã\x90âµ',
#  'daylesford',
#  'emokid_bastian',
#  'llore',
#  'pennykeating',
#  'lindaignarro',
#  'batum',
#  'hahafw',
#  'missiondistrict',
#  'rapey',
#  'furnishing',
#  'earthmoving',
#  'eyesonthegreen',
#  'ecoop',
#  'feliza',
#  'begin',
#  're-air',
#  'crazy.',
#  '//snipr.com/k5q0ni',
#  'pleasse',
#  '*did*',
#  'ksgill',
#  '666',
#  'lgbt',
#  'opera.com',
#  'shalamae',
#  'marchhousebooks',
#  'jaylorfan',
#  'bedlam',
#  'cancerous',
#  'lease',
#  'noturstar23',
#  'm*',
#  'd_n_t',
#  'roflmaomfworking',
#  'hr2',
#  'campbellx',
#  'ondumb',
#  'keep',
#  'victorcina',
#  'dawno',
#  'yesssssssssss.tariks',
#  'jackbeats',
#  'empoleon',
#  'oh-so-cute',
#  'xmiyix',
#  'bap',
#  'lasvegasjen',
#  'yepp..',
#  'topobox',
#  'mister_showtime',
#  'smurfsgetting',
#  'buschgardens',
#  'bsbtby',
#  'ice/heat/ice',
#  'dawnallcot',
#  'ioooo',
#  'robotfactory',
#  'tunred',
#  'reverse',
#  '1192tom',
#  'myfavoritething',
#  'dinns',
#  'mayeeahi',
#  'sorry.has',
#  'guyzzzzzzzzz',
#  'chakotay_',
#  'proposalbackstreet',
#  'steered',
#  'carton',
#  'mini-sharks',
#  'nerfed',
#  'ade1965',
#  '8/8',
#  'ms_muffet',
#  'mmmm',
#  "diu/lan/gau'ing",
#  'froelich',
#  'and1001',
#  'povray',
#  'sucks.lakers',
#  'spafax_arjun',
#  'thought.theres',
#  'aroundloves',
#  'fmlalmost',
#  'hilarydouglas',
#  'brentemery',
#  'xxhurt',
#  'incredable',
#  'problly',
#  'magnific',
#  'sheeot',
#  '//plurk.com/p/svlqdin',
#  'flowerhorn',
#  "n'more",
#  'scheer',
#  'day_b',
#  'heigl',
#  'kindareal',
#  'xlate',
#  'aidan',
#  'wah.awesome',
#  'restaurant/one',
#  'jeninblack',
#  'sunshinee',
#  'petecarroll',
#  'mini-golf',
#  'shiprice.comdone',
#  'god.i',
#  'pre-holiday-work',
#  'serious..lol',
#  'creppy',
#  'jeffreynew',
#  'sirpoins',
#  'savannahkenney',
#  '//twitpic.com/6q5bg',
#  'ewenrick',
#  '=/ca',
#  'mesirii',
#  'makikita',
#  'thehitlist',
#  'kallio',
#  'borderline',
#  'ougi',
#  '.8',
#  'guilfest',
#  "'scrapheap",
#  'one.so',
#  'udates',
#  'nobitchassnessfriday',
#  'taylorfied',
#  'cut..',
#  'prophesisingi',
#  'leprakhauns',
#  'jste',
#  'anniemoon',
#  'brizzlebabber',
#  'rome_zoe',
#  'minxalicious',
#  'app.ok',
#  'lyndleeeee',
#  'yiruma',
#  'snickerdoodles',
#  'machoman',
#  'aeneas',
#  'wimcoekaerts',
#  'julie419',
#  'happyjodi',
#  'yargman',
#  'finalizing',
#  'chardzz',
#  '//bit.ly/mkfuu',
#  'ã\x90â³ã\x90â',
#  'ardens',
#  'raise',
#  'june,4',
#  'packtplastik',
#  'maa',
#  'lihzee',
#  'dolfinamie',
#  'mandyyyyyyy',
#  'houston',
#  'fillmmaking',
#  'soul-destroying',
#  'smile4mepatty',
#  'i270',
#  'catrinajane',
#  'oculustigris',
#  'withdrawals..',
#  'form',
#  'kurathaillest6',
#  'spookily',
#  'delores',
#  '19-year',
#  'reseda',
#  'suzyelizabeth',
#  'lumiere',
#  'familiar',
#  'eduction',
#  'tweetsrecording',
#  "90's/early",
#  "_don't_",
#  'ã\x91â\x87ã\x90â¸ã\x91â\x82ã\x90â°ã\x91â\x8eã\x91â\x82',
#  'cinderfella',
#  'irrespctive',
#  'straithoodie',
#  ...}

# %%
fr1=nltk.FreqDist(vocabulary)

# %%
fr1.plot(20)

# %%
fr2=nltk.FreqDist(voc)

# %%
fr2.plot(10)
# Out:
# /home/mehrdad/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/mehrdad/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
'times' in word_tokenize(sent[2])
# Out:
# False

# %%
#word=[('times' in word_tokenize(sent[i])) and (tag[i]==0) for i in range(len(twitter))]

# %%
#sum(word)

# %%
def nk(word,given_tag):#total number of words whose tag is given_tag
    word_in_sen=[((word in word_tokenize(sent[i])) and (tag[i]==given_tag)) for i in range(len(twitter))]
    nj=sum(word_in_sen)
    return nj

# %%
nk('times',4)
# Out:
# 1191

# %%
def n(given_tag):
    m1=[word_tokenize(w) for w in twitter[tag==given_tag][6]]
    m2=np.concatenate(m1)
    m3=set(m2)
    return len(m3)

# %%
def pr(w,given_tag):
    n_k=nk(w,given_tag)
    n_n=n(given_tag)
    prob=(n_k+1)/(n_n+len(voc))
    return prob

# %%
n(0)
# Out:
# 217770

# %%
def sentiment(new):
    tkn=word_tokenize(new)
    p1=1
    q1=1
    for w in tkn:
        p1=p1*pr(w,0)
        q1=q1*pr(w,4)
    p1=p(0)*p1
    q1=p(4)*q1
    if p1>q1:
        return "Negative"
    else:
        return "Positive"

# %%
sentiment('i like movie')

# %%
sentiment('i love my wife very much. she is my heart')
# Out:
# 'Negative'

# %%
sentiment('hate')
# Out:
# 'Negative'

# %%
sentiment('happy')
# Out:
# 'Positive'

# %%
sentiment('i love you')
# Out:
# 'Positive'
